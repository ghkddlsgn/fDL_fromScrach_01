# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = w1 * x1 + w2 * x2
    return 1 if tmp > theta else 0

# %%
import numpy as np

def OR(x:np.array):
    theta = 1
    w = [1, 1]
    b = 0

    y_hat = np.sum((w * x)+b)
    return 1 if y_hat >= theta else 0

print(OR(np.array([0,0])))
print(OR(np.array([1,0])))
print(OR(np.array([0,1])))
print(OR(np.array([1,1])))
# Out:
# 0
# 1
# 1
# 1

# %%
def step_function(x):
    y = x > 0
    return y.astype(int)

# %%
def relu(x):
    return np.maximum(0,x)

def sigmoid(x):
        return 1 / (1 + np.exp(-x))

# %%
def init_network():
    network = {}
    network['W1'] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network['b1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network['b2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[0.1, 0.3], [0.2, 0.4]])
    network['b3'] = np.array([0.1, 0.2])
    return network

def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    def sigmoid(x):
        return 1 / (1 + np.exp(-x))
    
    def identity_function(x):
        return x

    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = identity_function(a3)
    return y

network = init_network()
x = np.array([1.0, 0.5])
y = forward(network, x)
print(y)  # [0.31682708 0.69627909]
# Out:
# [0.31682708 0.69627909]

# %%
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a - c)
    sum_exp_a = np.sum(np.exp(a-c))
    y = exp_a / sum_exp_a
    return y

# %%
from sklearn.datasets import fetch_openml
import pickle

# Load MNIST (70,000 images, 28x28 flattened to 784 features)
mnist = fetch_openml('mnist_784', version=1, as_frame=False)
# Save MNIST (path relative to project root)
with open('study/ch01/mnist.pkl', 'wb') as f:
    pickle.dump(mnist, f)

# %%
import matplotlib.pyplot as plt
with open("study/ch01/mnist.pkl", "rb") as f:
    mnist = pickle.load(f)
X, y = mnist.data, mnist.target
img = X[0].reshape(28, 28)
plt.imshow(img)

# %%
def init_network():
    with open("study/ch01/mnist.pkl", "rb") as f:
        mnist = pickle.load(f)
    
    return network

def predict(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    a1 = np.dot(x, W1) + b1    
    z1 = sigmoid(a1)
